# %% [markdown]
# <a href="https://colab.research.google.com/github/Adikto983-del/DasarPPLG-X-2627/blob/main/tugas_program_menghitung_luassegitiga0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TUGAS MEMBUAT MENGHITUNG BANGUN DATAR LUASSEGITIGA
#
# nama kelompok:antodonatur
#
# 1.Adikto dwi pratama hamdi
#
# 2.evan
#
# 3.hana
#
# 4.aulia
#
# 5.gavin
#
# 6.geisan
#
# 7.reno

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile luassegitiga.cpp
# #include <iostream>
# using namespace std;
# int main ()
# {
#  int a,t,luas;
# cout<<"program aplikasi menghitung luassegitiga"<<endl;
# cout<<"masukkan luas segitiga "<<endl;
# cin>>a;
# cout<<" masukkan tinggi segitiga "<<endl;
# cin>>t;
# luas=0.5*a*t;
# cout<<" luas segitiga adalah"<<luas<<endl;
#  return 0;
# }
# Out:
# Overwriting luassegitiga.cpp

# %%
# !g++ luassegitiga.cpp -o main

# %%
# !./main
# Out:
# program aplikasi menghitung luassegitiga
# masukkan luas segitiga
# 10
#  masukkan tinggi segitiga
# 6
#  luas segitiga adalah30
