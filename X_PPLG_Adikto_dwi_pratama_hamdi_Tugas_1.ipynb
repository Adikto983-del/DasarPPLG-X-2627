# %% [markdown]
# <a href="https://colab.research.google.com/github/Adikto983-del/DasarPPLG-X-2627/blob/main/X_PPLG_Adikto_dwi_pratama_hamdi_Tugas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tugas1 praktik membuat tipe data dan variabel
#
# nama kelompok: anto donatur nama anggota :
#
# 1.Adikto dwi pratama hamdi
#
# 2.Reno Ruzain Arafah
#
# 3.Ghaisan faiza rizky
#
# 4.Aulia Rahma Thalita
#
# 5.evan fadhila
#
# 6.Gavin athallah D.

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile praktik_variabel.cpp
# #include<iostream>
# #include<string>
# using namespace std;
# int main()
# {
# // Deklarasi Variabel dan Tipe Data
# string namaBarang = "Iphone X";
# int jumlah =2;
# float harga = 7800000.50;
# char kategori = 'A';
# bool tersedia = true;
#
# // Menampilkan Output ke Layar
# cout<<"=== DATA INVENTARIS ==="<<endl;
# cout<<"Nama Barang:"<<namaBarang<<endl;
# cout<<"Kategori: "<<kategori << endl;
# cout<<"Jumlah :"<<jumlah<<endl;
# cout<<"Harga:Rp"<<harga<<endl;
# cout<<"Tersedia :"<<tersedia<<"(1=Ya,0=Tidak)"<<endl;
# cout<<"========================"<<endl;
# return 0;
# }
# Out:
# Overwriting praktik_variabel.cpp

# %%
# !g++ praktik_variabel.cpp -o praktik_variabel
# !./praktik_variabel
# Out:
# === DATA INVENTARIS ===
# Nama Barang:Iphone X
# Kategori: A
# Jumlah :2
# Harga:Rp7.8e+06
# Tersedia :1(1=Ya,0=Tidak)
# ...
