# %% [markdown]
# <a href="https://colab.research.google.com/github/Adikto983-del/DasarPPLG-X-2627/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# tugas2 praktik membuat tipe data dan variabel
#
# nama kelompok: anto donatur nama anggota :
#
# 1.Adikto dwi pratama hamdi
#
# 2.Reno Ruzain Arafah
#
# 3.Ghaisan faiza rizky
#
# 4.Aulia Rahma Thalita
#
# 5.evan fadhila
#
# 6.Gavin athallah D.

# %%
# !g++ --version
# Out:
# g++ (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.

# %%
# %%writefile input_data.cpp
# #include <iostream>
# #include <string>
# using namespace std;
#
# int main() {
#     string namaSiswa;
#     int umur;
#
#     cout << "Masukkan Nama (1 Kata) : ";
#     cin >> namaSiswa;
#
#     cout << "Masukkan Umur Anda     : ";
#     cin >> umur;
#
#     cout << "\nHalo " << namaSiswa << ", ternyata umur kamu " << umur << " tahun ya!" << endl;
#     return 0;
# }
# Out:
# Overwriting input_data.cpp

# %%
# !g++ input_data.cpp -o input_data
# !./input_data
# Out:
# Masukkan Nama (1 Kata) : dikto
# Masukkan Umur Anda     : 16
#
# Halo dikto, ternyata umur kamu 16 tahun ya!
